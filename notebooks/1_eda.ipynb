# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.value_counts()
# Out:
# age  sex     bmi    children  smoker  region     charges
# 19   male    30.59  0         no      northwest  1639.56310     2
# 48   female  25.85  3         yes     southeast  24180.93350    1
#              22.80  0         no      southwest  8269.04400     1
# 47   male    47.52  1         no      southeast  8083.91980     1
#              38.94  2         yes     southeast  44202.65360    1
#                                                                ..
# 30   male    44.22  2         no      southeast  4266.16580     1
#              38.83  1         no      southeast  18963.17192    1
#              37.80  2         yes     southwest  39241.44200    1
#              37.43  3         no      northeast  5428.72770     1
# 31   female  29.26  1         no      southeast  4350.51440     1
# Name: count, Length: 1337, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = ['age', 'bmi', 'children', 'charges']
plt.figure(figsize=(15, 10))

for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df[col])
    plt.title(f'Box plot of {col}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['bmi'], kde=True)
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['charges'], kde=True)
plt.title('Distribution of Charges')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='region', data=df)
plt.title('Distribution of Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='smoker', data=df)
plt.title('Distribution of Smoker')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.show()

# %%
smoker_counts = df['smoker'].value_counts()
total_individuals = len(df)

pmf_smoker = smoker_counts / total_individuals

print("Probability Mass Function (PMF) for Smoker:")
print(pmf_smoker)
# Out:
# Probability Mass Function (PMF) for Smoker:
# smoker
# no     0.795217
# yes    0.204783
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 4))
pmf_smoker.plot(kind='bar')
plt.title('Probability Mass Function (PMF) for Smoker')
plt.xlabel('Smoker')
plt.ylabel('Probability')
plt.xticks(rotation=0)
plt.show()

# %%
region_counts = df['region'].value_counts()
total_individuals = len(df)

pmf_region = region_counts / total_individuals

print("Probability Mass Function (PMF) for Region:")
print(pmf_region)
# Out:
# Probability Mass Function (PMF) for Region:
# region
# southeast    0.272048
# southwest    0.242900
# northwest    0.242900
# northeast    0.242152
# Name: count, dtype: float64

# %%
plt.figure(figsize=(8, 6))
pmf_region.plot(kind='bar')
plt.title('Probability Mass Function (PMF) for Region')
plt.xlabel('Region')
plt.ylabel('Probability')
plt.xticks(rotation=0)
plt.show()

# %%
sex_counts = df['sex'].value_counts()
total_individuals = len(df)

pmf_sex = sex_counts / total_individuals

print("Probability Mass Function (PMF) for Sex:")
print(pmf_sex)
# Out:
# Probability Mass Function (PMF) for Sex:
# sex
# male      0.505232
# female    0.494768
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 4))
pmf_sex.plot(kind='bar')
plt.title('Probability Mass Function (PMF) for Sex')
plt.xlabel('Sex')
plt.ylabel('Probability')
plt.xticks(rotation=0)
plt.show()

# %%
# Sort the data
sorted_charges = np.sort(df['charges'])

# Calculate the CDF
cdf_charges = np.arange(1, len(sorted_charges) + 1) / len(sorted_charges)

# Find the CDF value for charges less than 10k
cdf_less_than_10k = cdf_charges[sorted_charges < 10000][-1] if any(sorted_charges < 10000) else 0

print(f"The CDF for charges less than 10,000 is: {cdf_less_than_10k:.4f}")

# Optional: Plot the CDF
plt.figure(figsize=(10, 6))
plt.plot(sorted_charges, cdf_charges)
plt.axvline(x=10000, color='red', linestyle='--', label='10k')
plt.title('CDF of Charges')
plt.xlabel('Charges')
plt.ylabel('CDF')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The CDF for charges less than 10,000 is: 0.5321

# %%
# Sort the data
sorted_age = np.sort(df['age'])

# Calculate the CDF
cdf_age = np.arange(1, len(sorted_age) + 1) / len(sorted_age)

# Find the CDF value for age less than or equal to 20
cdf_less_than_equal_20 = cdf_age[sorted_age <= 20][-1] if any(sorted_age <= 20) else 0

# Probability of age greater than 20 is 1 - CDF(age <= 20)
probability_greater_than_20 = 1 - cdf_less_than_equal_20

print(f"The probability of age being greater than 20 is: {probability_greater_than_20:.4f}")

# Optional: Plot the CDF
plt.figure(figsize=(10, 6))
plt.plot(sorted_age, cdf_age)
plt.axvline(x=20, color='red', linestyle='--', label='20')
plt.title('CDF of Age')
plt.xlabel('Age')
plt.ylabel('CDF')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The probability of age being greater than 20 is: 0.8759

# %%
# Filter the DataFrame for smokers
smokers_df = df[df['smoker'] == 'yes'].copy()

# Sort the charges for smokers
sorted_charges_smokers = np.sort(smokers_df['charges'])

# Calculate the CDF for smokers
cdf_charges_smokers = np.arange(1, len(sorted_charges_smokers) + 1) / len(sorted_charges_smokers)

# Plot the CDF for smokers
plt.figure(figsize=(10, 6))
plt.plot(sorted_charges_smokers, cdf_charges_smokers)
plt.title('CDF of Charges for Smokers')
plt.xlabel('Charges')
plt.ylabel('CDF')
plt.grid(True)
plt.show()

# %%
# Filter the DataFrame for non-smokers
non_smokers_df = df[df['smoker'] == 'no'].copy()

# Sort the charges for non-smokers
sorted_charges_non_smokers = np.sort(non_smokers_df['charges'])

# Calculate the CDF for non-smokers
cdf_charges_non_smokers = np.arange(1, len(sorted_charges_non_smokers) + 1) / len(sorted_charges_non_smokers)

# Plot the CDF for non-smokers
plt.figure(figsize=(10, 6))
plt.plot(sorted_charges_non_smokers, cdf_charges_non_smokers)
plt.title('CDF of Charges for Non-Smokers')
plt.xlabel('Charges')
plt.ylabel('CDF')
plt.grid(True)
plt.show()

# %%
ninety_percentile_charges = df['charges'].quantile(0.90)
print(f"The 90th percentile of charges is: {ninety_percentile_charges:.2f}")
# Out:
# The 90th percentile of charges is: 34831.72

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='sex', y='bmi', data=df)
plt.title('BMI Distribution by Sex')
plt.xlabel('Sex')
plt.ylabel('BMI')
plt.show()

# %%
ninety_fifth_percentile_charges = df['charges'].quantile(0.95)
print(f"The 95th percentile of charges (minimum value of the top 5%) is: {ninety_fifth_percentile_charges:.2f}")
# Out:
# The 95th percentile of charges (minimum value of the top 5%) is: 41181.83

# %%
ninety_ninth_percentile_charges = df['charges'].quantile(0.99)
print(f"The 99th percentile of charges (minimum value of the top 1%) is: {ninety_ninth_percentile_charges:.2f}")
# Out:
# The 99th percentile of charges (minimum value of the top 1%) is: 48537.48

# %%
max_charges = df['charges'].max()
print(f"The maximum charge is: {max_charges:.2f}")
# Out:
# The maximum charge is: 63770.43

# %%
# Filter the DataFrame for smokers
smokers_df = df[df['smoker'] == 'yes'].copy()

# Sort the BMI for smokers
sorted_bmi_smokers = np.sort(smokers_df['bmi'])

# Calculate the CDF for smokers
cdf_bmi_smokers = np.arange(1, len(sorted_bmi_smokers) + 1) / len(sorted_bmi_smokers)

# Plot the CDF for smokers
plt.figure(figsize=(10, 6))
plt.plot(sorted_bmi_smokers, cdf_bmi_smokers)
plt.title('CDF of BMI for Smokers')
plt.xlabel('BMI')
plt.ylabel('CDF')
plt.grid(True)
plt.show()

# %%
# Filter the DataFrame for non-smokers
non_smokers_df = df[df['smoker'] == 'no'].copy()

# Sort the BMI for non-smokers
sorted_bmi_non_smokers = np.sort(non_smokers_df['bmi'])

# Calculate the CDF for non-smokers
cdf_bmi_non_smokers = np.arange(1, len(sorted_bmi_non_smokers) + 1) / len(sorted_bmi_non_smokers)

# Plot the CDF for non-smokers
plt.figure(figsize=(10, 6))
plt.plot(sorted_bmi_non_smokers, cdf_bmi_non_smokers)
plt.title('CDF of BMI for Non-Smokers')
plt.xlabel('BMI')
plt.ylabel('CDF')
plt.grid(True)
plt.show()

# %%
# Sort the charges data
sorted_charges = np.sort(df['charges'])

# Calculate the CDF
cdf_charges = np.arange(1, len(sorted_charges) + 1) / len(sorted_charges)

# Plot the CDF
plt.figure(figsize=(10, 6))
plt.plot(sorted_charges, cdf_charges)
plt.title('CDF of Charges')
plt.xlabel('Charges')
plt.ylabel('CDF')
plt.grid(True)
plt.show()

# %%
import scipy.stats as stats

# Apply log transformation to the 'charges' column
df['log_charges'] = np.log(df['charges'])

# Plot histogram of log_charges
plt.figure(figsize=(10, 6))
sns.histplot(df['log_charges'], kde=True)
plt.title('Distribution of Log-transformed Charges')
plt.xlabel('Log(Charges)')
plt.ylabel('Frequency')
plt.show()

# Create a Q-Q plot to check for normality
plt.figure(figsize=(6, 6))
stats.probplot(df['log_charges'], dist="norm", plot=plt)
plt.title('Q-Q Plot of Log-transformed Charges')
plt.show()

# %%
from scipy.stats import pareto

# Fit the Pareto distribution to the charges data
# The fit function returns the shape parameter (b) and the location parameter (loc)
b, loc, scale = pareto.fit(df['charges'])

print(f"Pareto distribution parameters:")
print(f"Shape (b): {b:.4f}")
print(f"Location (loc): {loc:.4f}")
print(f"Scale (scale): {scale:.4f}")

# Plot the histogram of the charges data
plt.figure(figsize=(10, 6))
plt.hist(df['charges'], bins=50, density=True, alpha=0.6, label='Data')

# Plot the fitted Pareto distribution
# Generate x values for the fitted distribution
x = np.linspace(df['charges'].min(), df['charges'].max(), 100)
plt.plot(x, pareto.pdf(x, b, loc=loc, scale=scale), 'r-', lw=2, label='Fitted Pareto PDF')

plt.title('Fitted Pareto Distribution to Charges Data')
plt.xlabel('Charges')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pareto distribution parameters:
# Shape (b): 22626400.3590
# Location (loc): -274877905822.1260
# Scale (scale): 274877906943.9998

# %%
from scipy.stats import lognorm

# Filter the DataFrame for smokers and non-smokers
smokers_df = df[df['smoker'] == 'yes'].copy()
non_smokers_df = df[df['smoker'] == 'no'].copy()

# Fit log-normal distribution to charges for smokers
s_smokers, loc_smokers, scale_smokers = lognorm.fit(smokers_df['charges'], floc=0)

# Fit log-normal distribution to charges for non-smokers
s_non_smokers, loc_non_smokers, scale_non_smokers = lognorm.fit(non_smokers_df['charges'], floc=0)

# --- Plotting for Smokers ---
# Sort the charges for smokers
sorted_charges_smokers = np.sort(smokers_df['charges'])
# Calculate the empirical CDF for smokers
cdf_charges_smokers = np.arange(1, len(sorted_charges_smokers) + 1) / len(sorted_charges_smokers)

plt.figure(figsize=(10, 6))
plt.plot(sorted_charges_smokers, cdf_charges_smokers, label='Empirical CDF (Smokers)')

# Plot the theoretical log-normal CDF for smokers
x_smokers = np.linspace(smokers_df['charges'].min(), smokers_df['charges'].max(), 100)
plt.plot(x_smokers, lognorm.cdf(x_smokers, s_smokers, loc=loc_smokers, scale=scale_smokers), 'r-', lw=2, label='Fitted Log-normal CDF (Smokers)')

plt.title('CDF of Charges with Fitted Log-normal Distribution (Smokers)')
plt.xlabel('Charges')
plt.ylabel('CDF')
plt.legend()
plt.grid(True)
plt.show()

# --- Plotting for Non-Smokers ---
# Sort the charges for non-smokers
sorted_charges_non_smokers = np.sort(non_smokers_df['charges'])
# Calculate the empirical CDF for non-smokers
cdf_charges_non_smokers = np.arange(1, len(sorted_charges_non_smokers) + 1) / len(sorted_charges_non_smokers)

plt.figure(figsize=(10, 6))
plt.plot(sorted_charges_non_smokers, cdf_charges_non_smokers, label='Empirical CDF (Non-Smokers)')

# Plot the theoretical log-normal CDF for non-smokers
x_non_smokers = np.linspace(non_smokers_df['charges'].min(), non_smokers_df['charges'].max(), 100)
plt.plot(x_non_smokers, lognorm.cdf(x_non_smokers, s_non_smokers, loc=loc_non_smokers, scale=scale_non_smokers), 'r-', lw=2, label='Fitted Log-normal CDF (Non-Smokers)')

plt.title('CDF of Charges with Fitted Log-normal Distribution (Non-Smokers)')
plt.xlabel('Charges')
plt.ylabel('CDF')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Filter the DataFrame for non-smokers
non_smokers_df = df[df['smoker'] == 'no'].copy()

# Apply log transformation to charges for non-smokers (if not already done)
if 'log_charges' not in non_smokers_df.columns:
    non_smokers_df['log_charges'] = np.log(non_smokers_df['charges'])

# Calculate the mean and standard deviation of the log-transformed charges for non-smokers
mean_log_charges_non_smokers = non_smokers_df['log_charges'].mean()
std_log_charges_non_smokers = non_smokers_df['log_charges'].std()

print(f"Mean of log-transformed charges for non-smokers: {mean_log_charges_non_smokers:.4f}")
print(f"Standard deviation of log-transformed charges for non-smokers: {std_log_charges_non_smokers:.4f}")
# Out:
# Mean of log-transformed charges for non-smokers: 8.7882
# Standard deviation of log-transformed charges for non-smokers: 0.7442

# %%
# Filter the DataFrame for smokers
smokers_df = df[df['smoker'] == 'yes'].copy()

# Apply log transformation to charges for smokers (if not already done)
if 'log_charges' not in smokers_df.columns:
    smokers_df['log_charges'] = np.log(smokers_df['charges'])

# Calculate the mean and standard deviation of the log-transformed charges for smokers
mean_log_charges_smokers = smokers_df['log_charges'].mean()
std_log_charges_smokers = smokers_df['log_charges'].std()

print(f"Mean of log-transformed charges for smokers: {mean_log_charges_smokers:.4f}")
print(f"Standard deviation of log-transformed charges for smokers: {std_log_charges_smokers:.4f}")
# Out:
# Mean of log-transformed charges for smokers: 10.3041
# Standard deviation of log-transformed charges for smokers: 0.3875

# %%
# Calculate the pooled standard deviation
pooled_std = np.sqrt(((len(smokers_df) - 1) * std_log_charges_smokers**2 + (len(non_smokers_df) - 1) * std_log_charges_non_smokers**2) / (len(smokers_df) + len(non_smokers_df) - 2))

# Calculate Cohen's d
cohens_d = (mean_log_charges_smokers - mean_log_charges_non_smokers) / pooled_std

print(f"Cohen's d (effect size) for the difference in log-transformed charges between smokers and non-smokers: {cohens_d:.4f}")
# Out:
# Cohen's d (effect size) for the difference in log-transformed charges between smokers and non-smokers: 2.2078

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='charges', hue='smoker', fill=True)
plt.title('Kernel Density Estimate of Charges by Smoker Status')
plt.xlabel('Charges')
plt.ylabel('Density')
plt.show()

# %%
# Calculate skewness and kurtosis for original charges
skewness_charges = df['charges'].skew()
kurtosis_charges = df['charges'].kurtosis()

print(f"Skewness of Charges: {skewness_charges:.4f}")
print(f"Kurtosis of Charges: {kurtosis_charges:.4f}")

print("-" * 30)

# Calculate skewness and kurtosis for log-transformed charges
skewness_log_charges = df['log_charges'].skew()
kurtosis_log_charges = df['log_charges'].kurtosis()

print(f"Skewness of Log-transformed Charges: {skewness_log_charges:.4f}")
print(f"Kurtosis of Log-transformed Charges: {kurtosis_log_charges:.4f}")
# Out:
# Skewness of Charges: 1.5159
# Kurtosis of Charges: 1.6063
# ------------------------------
# Skewness of Log-transformed Charges: -0.0901
# Kurtosis of Log-transformed Charges: -0.6367

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['charges'], alpha=0.5)
plt.title('Age vs. Charges (Scatter Plot)')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.stripplot(x='sex', y='charges', data=df, jitter=True, alpha=0.5)
plt.title('Charges vs. Sex (Stripplot with Jitter)')
plt.xlabel('Sex')
plt.ylabel('Charges')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.stripplot(x='children', y='charges', data=df, jitter=True, alpha=0.5)
plt.title('Charges vs. Number of Children (Stripplot with Jitter)')
plt.xlabel('Number of Children')
plt.ylabel('Charges')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.stripplot(x='smoker', y='charges', data=df, jitter=True, alpha=0.5)
plt.title('Charges vs. Smoker Status (Stripplot with Jitter)')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['bmi'], df['charges'], alpha=0.5)
plt.title('BMI vs. Charges (Scatter Plot)')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.grid(True)
plt.show()

# %%
pearson_corr = df['age'].corr(df['charges'], method='pearson')
spearman_corr = df['age'].corr(df['charges'], method='spearman')

print(f"Pearson correlation between Age and Charges: {pearson_corr:.4f}")
print(f"Spearman correlation between Age and Charges: {spearman_corr:.4f}")
# Out:
# Pearson correlation between Age and Charges: 0.2990
# Spearman correlation between Age and Charges: 0.5344

# %%
pearson_corr_bmi_charges = df['bmi'].corr(df['charges'], method='pearson')
spearman_corr_bmi_charges = df['bmi'].corr(df['charges'], method='spearman')

print(f"Pearson correlation between BMI and Charges: {pearson_corr_bmi_charges:.4f}")
print(f"Spearman correlation between BMI and Charges: {spearman_corr_bmi_charges:.4f}")
# Out:
# Pearson correlation between BMI and Charges: 0.1983
# Spearman correlation between BMI and Charges: 0.1194

# %%
# Convert 'sex' to numerical (0 for female, 1 for male)
df['sex_numeric'] = df['sex'].apply(lambda x: 1 if x == 'male' else 0)

# Calculate the Pearson correlation between 'sex_numeric' and 'charges'
pearson_corr_sex_charges = df['sex_numeric'].corr(df['charges'], method='pearson')

# Calculate the Spearman correlation between 'sex_numeric' and 'charges'
spearman_corr_sex_charges = df['sex_numeric'].corr(df['charges'], method='spearman')

print(f"Pearson correlation between Sex (numeric) and Charges: {pearson_corr_sex_charges:.4f}")
print(f"Spearman correlation between Sex (numeric) and Charges: {spearman_corr_sex_charges:.4f}")
# Out:
# Pearson correlation between Sex (numeric) and Charges: 0.0573
# Spearman correlation between Sex (numeric) and Charges: 0.0095

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='bmi', y='charges', hue='smoker', alpha=0.6)
plt.title('BMI vs. Charges, Colored by Smoker Status')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='charges', hue='sex', alpha=0.6)
plt.title('Age vs. Charges, Colored by Sex')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.grid(True)
plt.show()

# %%
df['charges'].mean()
# Out:
# np.float64(13270.422265141257)

# %%
import numpy as np
means = [df['charges'].sample(frac=1, replace=True).mean() for _ in range(1000)]
ci = np.percentile(means, [2.5, 97.5])
